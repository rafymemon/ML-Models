# %%
import pandas as pd
import numpy as np
from sklearn.datasets import make_classification

# %%
x, y = make_classification(n_features=5, n_redundant=0, n_informative=5, n_clusters_per_class=1)

# %%
df = pd.DataFrame(x, columns = ['col1', 'col2', 'col3', 'col4', 'col5'])
df['target'] = y
print(df.shape)
df.head()
# Out:
# (100, 6)
#        col1      col2      col3      col4      col5  target
# 0 -0.619514 -1.319685 -1.349580 -0.150258 -1.210049       0
# 1  0.348610  0.372853 -2.012462  1.509705  0.248382       1
# 2  0.042087  1.759043 -1.095543  2.232899  0.356007       1
# 3 -2.021016 -2.149515 -0.648229  0.024299 -0.605127       0
# 4 -2.450008 -0.554961  0.046063 -2.938177 -0.533751       0

# %%
# Function for row sampling
def sample_row(df, percent):
    return df.sample(int(percent*df.shape[0]), replace=True)

# %%
# Function for feature sampling
def sample_feature(df, percent):
    cols = random.sample(df.columns.tolist()[:-1], int(percent*(df.shape[1]-1)))
    return df[cols]

# %%
# Combined sampling
def combined_sampling(df, row_percent, col_percent):
    new_df = sample_rows(df, row_percent)
    return sample_features(new_df, col_percent)

# %%
# Different dataframe samples 
df1 = sample_row(df, 0.2)
df2 = sample_row(df, 0.2)
df3 = sample_row(df, 0.2)

# %%
print(df1.shape, ' ', df2.shape, ' ', df3.shape)
# Out:
# (20, 6)   (20, 6)   (20, 6)

# %%
from sklearn.tree import DecisionTreeClassifier
clf1 = DecisionTreeClassifier()
clf2 = DecisionTreeClassifier()
clf3 = DecisionTreeClassifier()

# %%
clf1.fit(df1.iloc[:, 0:5], df1.iloc[:, -1])
clf2.fit(df2.iloc[:, 0:5], df2.iloc[:, -1])
clf3.fit(df3.iloc[:, 0:5], df3.iloc[:, -1])
# Out:
# DecisionTreeClassifier()

# %%
from sklearn.tree import plot_tree

# %%
plot_tree(clf1)
# Out:
# [Text(0.5, 0.75, 'x[1] <= -0.13\ngini = 0.495\nsamples = 20\nvalue = [9, 11]'),
#  Text(0.25, 0.25, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(0.375, 0.5, 'True  '),
#  Text(0.75, 0.25, 'gini = 0.0\nsamples = 11\nvalue = [0, 11]'),
#  Text(0.625, 0.5, '  False')]

# %%
plot_tree(clf2)
# Out:
# [Text(0.6, 0.8333333333333334, 'x[1] <= -0.377\ngini = 0.375\nsamples = 20\nvalue = [5, 15]'),
#  Text(0.4, 0.5, 'x[2] <= -1.93\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.5, 0.6666666666666667, 'True  '),
#  Text(0.2, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6, 0.16666666666666666, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.8, 0.5, 'gini = 0.0\nsamples = 14\nvalue = [0, 14]'),
#  Text(0.7, 0.6666666666666667, '  False')]

# %%
plot_tree(clf3)
# Out:
# [Text(0.5, 0.75, 'x[1] <= 0.135\ngini = 0.455\nsamples = 20\nvalue = [13, 7]'),
#  Text(0.25, 0.25, 'gini = 0.0\nsamples = 13\nvalue = [13, 0]'),
#  Text(0.375, 0.5, 'True  '),
#  Text(0.75, 0.25, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(0.625, 0.5, '  False')]

# %%
clf1.predict(np.array([-1.330068,	-0.997048,	0.519954,	-2.483589,	0.521978]).reshape(1, 5))
# Out:
# C:\Users\Rafy Mustafa\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([0])

# %%
clf2.predict(np.array([-1.330068,	-0.997048,	0.519954,	-2.483589,	0.521978]).reshape(1, 5))
# Out:
# C:\Users\Rafy Mustafa\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([0])

# %%
clf3.predict(np.array([-1.330068,	-0.997048,	0.519954,	-2.483589,	0.521978]).reshape(1, 5))
# Out:
# C:\Users\Rafy Mustafa\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([0])
